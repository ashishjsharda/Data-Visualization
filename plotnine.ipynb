# %%
# !pip install plotnine
# Out:
# Collecting plotnine
#   Downloading plotnine-0.8.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 23.6 MB/s
# Requirement already satisfied: numpy>=1.19.0 in /opt/python/envs/default/lib/python3.8/site-packages (from plotnine) (1.21.5)
# Requirement already satisfied: matplotlib>=3.1.1 in /opt/python/envs/default/lib/python3.8/site-packages (from plotnine) (3.5.1)
# Collecting mizani>=0.7.3
#   Downloading mizani-0.7.4-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 5.0 MB/s
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/python/envs/default/lib/python3.8/site-packages (from plotnine) (0.13.1)
# Requirement already satisfied: patsy>=0.5.1 in /opt/python/envs/default/lib/python3.8/site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: scipy>=1.5.0 in /opt/python/envs/default/lib/python3.8/site-packages (from plotnine) (1.7.3)
# Requirement already satisfied: pandas>=1.1.0 in /opt/python/envs/default/lib/python3.8/site-packages (from plotnine) (1.3.5)
# Requirement already satisfied: descartes>=1.1.0 in /opt/python/envs/default/lib/python3.8/site-packages (from plotnine) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (3.0.8)
# Requirement already satisfied: cycler>=0.10 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (4.33.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (9.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (21.3)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 62.2 MB/s
# Requirement already satisfied: pytz>=2017.3 in /opt/python/envs/default/lib/python3.8/site-packages (from pandas>=1.1.0->plotnine) (2022.1)
# Requirement already satisfied: six in /opt/python/envs/default/lib/python3.8/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Installing collected packages: palettable, mizani, plotnine
# Successfully installed mizani-0.7.4 palettable-3.3.0 plotnine-0.8.0
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
n = 10
df = pd.DataFrame({'x': np.arange(n),
                   'y': np.arange(n),
                   'yfit': np.arange(n) + np.tile([-.2, .2], n//2),
                   'cat': ['a', 'b']*(n//2)})

# %%
(ggplot(df)
 + geom_col(aes('x', 'y', fill='cat'))
 + geom_point(aes('x', y='yfit', color='cat'))
 + geom_path(aes('x', y='yfit', color='cat'))
)
# Out:
# <ggplot: (8766676349835)>
